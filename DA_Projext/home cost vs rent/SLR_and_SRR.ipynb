# %%
import pandas as pd
import numpy as np

# %%
files = {
    'mean_listing_pricecut': 'mean_listings_price_cut.csv',
    'prcnt_listings_with_pricecut': 'percentage_of_listings_with_price_cut.csv',
    'avg_saleprice': 'median_sale price.csv',
    'avg_listing_price': 'avg_listing_price.csv',
    'avg_rental_price': 'avg_rentals.csv'
}

RegionName_ = ['United States', 'New York, NY','Los Angeles-Long Beach-Anaheim, CA','San Francisco, CA','San Jose, CA']

# %%
def read_data(file, **kw):
    df = pd.read_csv(file)
    df.sort_index(inplace=True)
    return df

# %%
mean_listing_pricecut=read_data( 'mean_listings_price_cut.csv')
prcnt_listings_with_pricecut=read_data('percentage_of_listings_with_price_cut.csv')
avg_saleprice=read_data('avg_sale price.csv')
avg_listing_price=read_data('avg_listing_price.csv')
avg_rental_price=read_data('avg_rentals.csv')

# %%
avg_rental_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 94 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionID    105 non-null    int64
#  1   RegionName  105 non-null    object
#  2   SizeRank    105 non-null    int64
#  3   2014-01     98 non-null     float64
#  4   2014-02     105 non-null    int64
#  5   2014-03     104 non-null    float64
#  6   2014-04     105 non-null    int64
#  7   2014-05     105 non-null    int64
#  8   2014-06     105 non-null    int64
#  9   2014-07     105 non-null    int64
#  10  2014-08     105 non-null    int64
#  11  2014-09     105 non-null    int64
#  12  2014-10     105 non-null    int64
#  13  2014-11     105 non-null    int64
#  14  2014-12     105 non-null    int64
#  15  2015-01     105 non-null    int64
#  16  2015-02     105 non-null    int64
#  17  2015-03     105 non-null    int64
#  18  2015-04     105 non-null    int64
# ...

# %% [markdown]
# # Calculating our own PRR
# We will base this off of Zillow Rental Data and Sales Data
#
# Get the median rental price by city
# Get the median sale price by city
# Divide the two
# Plot the result

# %%
avg_rental_price.drop('RegionID',1)
filtr=avg_rental_price[avg_rental_price.RegionName.isin(['United States', 'New York, NY','Los Angeles-Long Beach-Anaheim, CA','San Francisco, CA','San Jose, CA'])]
filtr
# Out:
#     RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0     102001                       United States         0   1356.0     1361
# 1     394913                        New York, NY         1   2205.0     2214
# 2     753899  Los Angeles-Long Beach-Anaheim, CA         2   1868.0     1879
# 11    395057                   San Francisco, CA        11   2134.0     2167
# 34    395059                        San Jose, CA        34   2137.0     2172
#
#     2014-03  2014-04  2014-05  2014-06  2014-07  ...  2020-10  2020-11  \
# 0    1367.0     1373     1378     1384     1390  ...     1712     1721
# 1    2224.0     2234     2244     2254     2264  ...     2437     2433
# 2    1890.0     1902     1913     1924     1935  ...     2529     2538
# 11   2199.0     2232     2264     2296     2328  ...     2916     2909
# 34   2207.0     2242     2276     2310     2344  ...     2920     2913
#
#     2020-12  2021-01  2021-02  2021-03  2021-04  2021-05  2021-06  2021-07
# ...
